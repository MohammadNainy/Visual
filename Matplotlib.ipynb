# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import os

# %%
src_file = os.path.join("..","Data","FuelConsumption.csv")
df = pd.read_csv(src_file)
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
plt.hist(df["FUELCONSUMPTION_COMB"])
# Out:
# (array([ 28., 226., 297., 236., 115.,  94.,  37.,  18.,  11.,   5.]),
#  array([ 4.7 ,  6.81,  8.92, 11.03, 13.14, 15.25, 17.36, 19.47, 21.58,
#         23.69, 25.8 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["FUELCONSUMPTION_COMB"]);

# %%
plt.hist(df["FUELCONSUMPTION_COMB"])
plt.xlabel("Fuel")
plt.ylabel("Number of car")
plt.title("Graph")
plt.show()

# %%
fig, ax= plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"]);

# %%
fig, ax= plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"])
ax.set_xlabel("Fuel")
ax.set_ylabel("Number of car")
ax.set_title("Graph")
plt.show()

# %%
fig ,ax =plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"])
ax.set(
    xlabel="Fuel",
    ylabel="Number",
    title="Graph"
);

# %%
fig ,ax =plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"],range=(-20,50));

# %%
fig ,ax =plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"],range=(0,30),histtype='step');

# %%
fig ,ax =plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"],range=(0,30),histtype='step',orientation='horizontal');

# %%
fig ,ax =plt.subplots()
ax.hist(df["FUELCONSUMPTION_COMB"],bins=45)
# Out:
# (array([ 3.,  4.,  6.,  8., 20., 30., 50., 67., 66., 57., 68., 80., 54.,
#         68., 59., 49., 40., 58., 30., 33., 19., 25., 17., 26., 13., 31.,
#         15., 13.,  9., 10.,  5.,  2.,  4.,  0.,  3.,  9.,  3.,  3.,  4.,
#          1.,  1.,  0.,  0.,  0.,  4.]),
#  array([ 4.7       ,  5.16888889,  5.63777778,  6.10666667,  6.57555556,
#          7.04444444,  7.51333333,  7.98222222,  8.45111111,  8.92      ,
#          9.38888889,  9.85777778, 10.32666667, 10.79555556, 11.26444444,
#         11.73333333, 12.20222222, 12.67111111, 13.14      , 13.60888889,
#         14.07777778, 14.54666667, 15.01555556, 15.48444444, 15.95333333,
#         16.42222222, 16.89111111, 17.36      , 17.82888889, 18.29777778,
#         18.76666667, 19.23555556, 19.70444444, 20.17333333, 20.64222222,
#         21.11111111, 21.58      , 22.04888889, 22.51777778, 22.98666667,
#         23.45555556, 23.92444444, 24.39333333, 24.86222222, 25.33111111,
#         25.8       ]),
# ...

# %%
n, bins, patches = plt.hist(df["FUELCONSUMPTION_COMB"],range=(0,30),bins=45)

# %%
print(n)
print(bins)
# Out:
# [  0.   0.   0.   0.   0.   0.   0.   3.   6.  14.  41.  57. 102.  88.
#   82. 107.  96.  65.  68.  71.  46.  27.  31.  33.  37.  22.  13.  19.
#    5.   3.   3.   4.  11.   7.   1.   1.   0.   0.   4.   0.   0.   0.
#    0.   0.   0.]
# [ 0.          0.66666667  1.33333333  2.          2.66666667  3.33333333
#   4.          4.66666667  5.33333333  6.          6.66666667  7.33333333
#   8.          8.66666667  9.33333333 10.         10.66666667 11.33333333
#  12.         12.66666667 13.33333333 14.         14.66666667 15.33333333
#  16.         16.66666667 17.33333333 18.         18.66666667 19.33333333
#  20.         20.66666667 21.33333333 22.         22.66666667 23.33333333
#  24.         24.66666667 25.33333333 26.         26.66666667 27.33333333
#  28.         28.66666667 29.33333333 30.        ]

# %%
fig , ax = plt.subplots(2)
ax[0].hist(df["FUELCONSUMPTION_COMB"],range=(0,30),histtype='step');
ax[1].hist(df["FUELCONSUMPTION_COMB"],range=(10,20),bins=30);

# %%
plt.boxplot(df["FUELCONSUMPTION_COMB"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22ed84c2450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22ed84cc790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22ed84c3390>],
#  'medians': [<matplotlib.lines.Line2D at 0x22ed84ce010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22ed94b4550>],
#  'means': []}

# %%
fig , ax = plt.subplots()
ax.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"])
ax.set(title="Graph",
       ylabel="Fuel")
plt.show()

# %%
fig , ax = plt.subplots()
ax.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"],showfliers=False)
ax.set(title="Graph",
       ylabel="Fuel")
# Out:
# [Text(0.5, 1.0, 'Graph'), Text(0, 0.5, 'Fuel')]

# %%
fig , (ax1,ax2) = plt.subplots(2)
ax1.hist(df["FUELCONSUMPTION_COMB"],range=(0,30),histtype='step');
ax1.set(title="Graph1",
        xlabel="Fuel",
        ylabel="Number"
       );
ax2.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"],showfliers=False,vert=False);
ax2.set(title="Graph",
       xlabel="Fuel");

# %%
fig , (ax1,ax2) = plt.subplots(2)
ax1.hist(df["FUELCONSUMPTION_COMB"],range=(0,30),histtype='step');
ax1.set(title="Graph1",
        xlabel="Fuel",
        ylabel="Number"
       );
ax2.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"],showfliers=False,vert=False);
ax2.set(title="Graph",
       xlabel="Fuel");

fig.suptitle("Total",fontsize="16",fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Total')

# %%
fig , (ax1,ax2) = plt.subplots(1,2)
ax1.hist(df["FUELCONSUMPTION_COMB"],range=(0,30));
ax1.set(title="Graph1",
        xlabel="Fuel",
        ylabel="Number"
       );
ax2.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"],showfliers=False);
ax2.set(title="Graph",
       ylabel="Fuel");

fig.suptitle("Total",fontsize="16",fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Total')

# %%
fig , (ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,4) )
ax1.hist(df["FUELCONSUMPTION_COMB"],range=(0,30));
ax1.set(title="Graph1",
        xlabel="Fuel",
        ylabel="Number"
       );
ax2.boxplot(df["FUELCONSUMPTION_COMB"],labels=["ALL"],showfliers=False);
ax2.set(title="Graph",
       ylabel="Fuel");

fig.suptitle("Total",fontsize="16",fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Total')

# %%
fig.savefig("figsave.png",dpi=100,transparent=True)

# %%
avg_by_ES = df.groupby("ENGINESIZE",as_index=False)["FUELCONSUMPTION_COMB"].mean().round(2)
avg_by_ES
# Out:
#     ENGINESIZE  FUELCONSUMPTION_COMB
# 0          1.0                  6.47
# 1          1.2                  6.55
# 2          1.3                  6.20
# 3          1.4                  7.84
# 4          1.5                  7.09
# 5          1.6                  8.29
# 6          1.8                  7.84
# 7          2.0                  9.03
# 8          2.1                  7.85
# 9          2.4                  9.58
# 10         2.5                  9.15
# 11         2.7                 10.32
# 12         3.0                 11.11
# 13         3.2                 11.21
# 14         3.3                 11.38
# 15         3.4                 10.38
# 16         3.5                 11.12
# 17         3.6                 12.70
# 18         3.7                 12.31
# 19         3.8                 11.69
# 20         4.0                 13.11
# 21         4.2                 15.22
# 22         4.3                 14.82
# 23         4.4                 13.57
# ...

# %%
plt.plot(avg_by_ES["ENGINESIZE"],avg_by_ES["FUELCONSUMPTION_COMB"]);

# %%
plt.plot(avg_by_ES["ENGINESIZE"],avg_by_ES["FUELCONSUMPTION_COMB"]);
plt.xticks(np.arange(1,10,0.5));

# %%
plt.bar(avg_by_ES["ENGINESIZE"],avg_by_ES["FUELCONSUMPTION_COMB"],bottom=6);

# %%
 plt.barh(avg_by_ES["ENGINESIZE"],avg_by_ES["FUELCONSUMPTION_COMB"]);

# %%
plt.scatter(df["ENGINESIZE"],df["CO2EMISSIONS"]);

# %%
plt.scatter(df["ENGINESIZE"],df["CO2EMISSIONS"],alpha=0.5,c=df["CYLINDERS"]);
plt.xlabel("ENGINE size")
plt.ylabel("CO2")
plt.show()

# %%
fig , ax = plt.subplots(figsize = (9,7))
ax.scatter(df["ENGINESIZE"],df["CO2EMISSIONS"],alpha=0.5,c=df["CYLINDERS"]);
ax.set(
    xlabel="ENGINE size",
    ylabel="CO2"
)
ax.tick_params(axis="x",labelrotation=90)
ax.tick_params(axis="y",labelsize=18)
ax.set_title("Graph",size=18)
ax.axvline(3.2,c="red",linestyle=":");
ax.annotate("ES = 3.2",xy=(3.3,400),size=10);
ax.grid(True)

# %%
df["FUELCONSUMPTION_COMB"].plot(kind='hist');

# %%
df["FUELCONSUMPTION_COMB"].hist();

# %%
df["FUELCONSUMPTION_COMB"].plot(kind='box');

# %%
df["FUELCONSUMPTION_COMB"].plot(kind='density');

# %%
df["FUELCONSUMPTION_COMB"].plot(kind='kde');

# %%
avg_by_cylinders= df.groupby(['CYLINDERS']).agg({'FUELCONSUMPTION_CITY':'mean',"FUELCONSUMPTION_HWY":'mean',"FUELCONSUMPTION_COMB":'mean'}).round(2)
avg_by_cylinders
# Out:
#            FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB
# CYLINDERS
# 3                          6.80                 5.60                  6.30
# 4                          9.88                 7.34                  8.74
# 5                         11.20                 7.97                  9.74
# 6                         13.60                 9.60                 11.80
# 8                         18.07                12.64                 15.63
# 10                        20.26                13.37                 17.17
# 12                        19.54                12.37                 16.31

# %%
avg_by_cylinders.plot(kind="box",figsize=(9,5));

# %%
avg_by_cylinders.plot(kind="line");

# %%
avg_by_cylinders.plot(kind="line",title="FUELCONSUMPTION",figsize=(9,7)
                     ,xticks=np.arange(2,13,1),ylim=(4,25),rot=45
                     );

# %%
avg_by_cylinders.plot(kind="bar",figsize=(9,5));

# %%
avg_by_cylinders.plot(kind="barh");

# %%
avg_by_cylinders.plot(kind="area");

# %%
fig , ax = plt.subplots(figsize=(9,5))
avg_by_cylinders.plot(kind="area",ax=ax)
# Out:
# <Axes: xlabel='CYLINDERS'>

# %%
fig , ax = plt.subplots(figsize=(9,5))
avg_by_cylinders.plot(kind="area",ax=ax,stacked=False);
ax.set(ylabel="Fuel",xlabel="Cylind",title="area graph");

# %%
df[["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"]].plot(kind="hist");

# %%
df[["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"]].plot(kind="hist",alpha=0.5,bins=30);

# %%
df[["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"]].hist();

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"]);

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"],figsize=(9,7),layout=(3,1));

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"],figsize=(9,7),layout=(3,1),sharex=True);

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY"],grid=False);

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"],layout=(1,3));

# %%
df.hist(column=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"],layout=(1,3),figsize=(9,4),sharey=True);
